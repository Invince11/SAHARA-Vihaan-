# %%
from PIL import Image
import pytesseract
import argparse
import cv2
import os
import sys
import numpy as np

# %%
src_path = 'C:/Users/Pakhi/Desktop/MLL/ImageToText/'

# %%
img = cv2.imread("8.jpg")
a = 1225

img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
kernel = np.ones((1, 1), np.uint8)
img = cv2.dilate(img, kernel, iterations=1)
img = cv2.erode(img, kernel, iterations=1)

# %%
cv2.imwrite(src_path + "removed_noise.png", img)
# Out:
# True

# %%
img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)

# %%
img.shape
# Out:
# (1643, 1662)

# %%
cv2.imwrite(src_path + "t.png", img)
# Out:
# True

# %%
Image.open(src_path + "t.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1662x1643 at 0x1599B858BA8>

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files (x86)/Tesseract-OCR/tesseract'

# %%
result = pytesseract.image_to_string(Image.open(src_path + "t.png"))
print(result)
# Out:
# M6493
# 8
# “KEEP THIS HEART
# WITH vou ALWAVS
# AS A REMINDER
#
# THAT I WILL ALWAYS
# LOVE YOU"
#
# ,

# %%
img = cv2.imread("url.jpg")
a = 1225

img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
kernel = np.ones((1, 1), np.uint8)
img = cv2.dilate(img, kernel, iterations=1)
img = cv2.erode(img, kernel, iterations=1)

# %%
cv2.imwrite(src_path + "removed_noise.png", img)
# Out:
# True

# %%
img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)

# %%
img.shape
# Out:
# (500, 285)

# %%
cv2.imwrite(src_path + "tr.png", img)
# Out:
# True

# %%
Image.open(src_path + "tr.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=285x500 at 0x1599B8652B0>

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files (x86)/Tesseract-OCR/tesseract'

# %%
result = pytesseract.image_to_string(Image.open(src_path + "tr.png"))
print(result)
# Out:
# There are sum
# people who put . 9
# down In life, mock ‘
# your dreams, and
# challenge your
# personality; they look
# like winners. ‘ But in
# actual fact, they are
#
# insecurities - d .
# jealousy. Do n- let I
# them pull you do "
# Believe and acc p
#
# yourself and hold onto
# what you believe in:
#
# only voicing oui their 35
